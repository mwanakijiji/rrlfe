# %%
# Makes a few plots for a talk slide, to show examples of synthetic spectra

# Created 2022 Sept. 12 by E.S.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import glob

# %%
stem = "/Users/bandari/Documents/git.repos/rrlfe/src/model_spectra/rrmods_all/original_ascii_files/"

# %%
file_list = glob.glob(stem + "*smo")

# %%
df = pd.read_csv(file_list[1], delim_whitespace=True, names=["wavel","flux","noise"])

fig, ax = plt.subplots()
ax.axis("off")

ax.plot(df["wavel"],df["flux"],color="k")
ax.set_xticks([])
ax.set_yticks([])
#ax.xaxis("off")
plt.tight_layout()
plt.savefig("junk6.jpg")
